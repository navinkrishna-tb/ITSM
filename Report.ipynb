# %% [markdown]
# # ML for ITSM

# %% [markdown]
# ### Business Problem:
#
# ABC tech needs improvement on their current IT Service Management. Upgrading the existing ITIL is not an option due to budgetary constraints. So ML becomes the alternative solution.
# Key Requirements possible through ML:
# 1. #### Identifying the priority of incoming Incidents:
#     Incidents are events that interrupts normal service.Higher priority incidents will cause huge economic losses
#     if not handled urgently. So identifying the priority beforehand ensures the optimized usage of the service desk.
# 2. #### Forecasting Incident Volume:
#      Forecasting the trend of incident volume to the next year will help ABC tech in preparing their service resources. Decisons regarding recruiting new staffs or improving server capablities can be taken early if the projections look to overload the existing infrastructure
# 3. #### Improving Customer Satisfaction:
#    Giving an estimated handle time for the customer soon after they registered a ticket will have a positive impact on the customer.

# %% [markdown]
# ### Dataset details:
#
# #### CI_name,CI_Cat	CI_Subcat
# Configuration Items (CIs) are those Service assets which are configurable and can be managed through Change Management.
#
# ####  WBS(Work breakdown Structure)
# Each WBS contains a sequence of tasks for the following project phases: Initiation and Planning Activities.
# #### Incident id
# Id of incident
#
# #### Status
# Status of incident
#
# #### Impact
# Impact is the measure of the extent of potential damage the incident may cause.
#
# #### Urgency
# Urgency is how quickly a resolution is required
#
# #### Priority
# Preference order for allocating the service desk resources.
# Priority Matrix of ABC Tech
#
# ![Priority Matrix of ABC Tech ](https://i.ibb.co/Q6xQLZf/Capture.png)
#
# #### Category
# Whether the record is an Incident or not. Req. for info is not incident
# ####  KB_number
# Id on the knowledge base
# #### No_of_Reassignments
# Number of times this incident has reassigned to departments.
#
# #### Open_Time
# Time when incident has logged.
#
# #### Reopen_Time
# Time when incident has reopened
#
# #### Resolved_Time
# This is when the service desk confirms that the user’s service has been restored to the required SLA level.
#
# #### Close_Time
# The time when incident is considered closed and the incident process ends
#
# #### Handle_Time_hrs
# Total hours taken to handle the incident
# #### Closure_Code
# Denotes the Reason for closing the incident
# #### No_of_Related_Interactions
# The total number of related interactions associated with current incident
# #### Related_Interaction
# Id of related interactions associated with current incident
# #### No_of_Related_Incidents
# The total number of related incidents associated with current incident
# ####  No_of_Related_Changes
# The total number of related changes to the service associated with current incident
# #### Related_Change
# Id of changes to the service associated with current incident

# %% [markdown]
# ## Objective 1: Forecasting Incident Volume

# %% [markdown]
# ### Data Preprocessing

# %% [markdown]
# ### EDA

# %% [markdown]
# ### Impact In Years And Quarters

# %% [markdown]
# <img src = "impact.png">

# %% [markdown]
# ### Modelling

# %% [markdown]
# ## Objective 2: Auto tagging the Priorities

# %% [markdown]
# ### Data Wrangling

# %% [markdown]
# ### EDA

# %%
import pandas as pd
df = pd.read_excel("Itsm_data.xlsx")

# %% [markdown]
# ## Visualization

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import rcParams

# %%
def box(feature, width, height):
    rcParams['figure.figsize'] = width, height
    sns.boxplot(x=feature ,y = "Priority",
                    data=df, palette = "rainbow")
    plt.xlabel(feature, fontsize=50)
    plt.ylabel('Priority', fontsize=50)
    plt.suptitle(feature + ' vs Priority', fontsize = 40)

# %% [markdown]
# ### 1. Distibution of Configuration Items Category with Priority

# %%
box( 'CI_Cat', 40,30)
plt.xticks(rotation = 45, fontsize =40)
plt.yticks(fontsize =40)
plt.suptitle(' CI_Cat vs Priority', fontsize = 60)
# Out:
# Text(0.5, 0.98, ' CI_Cat vs Priority')

# %% [markdown]
# ### 2. Distibution of Configuration Items Subcategory with Priority

# %%
box( 'CI_Subcat', 40,30)
plt.xticks(rotation = 90, fontsize =30)
plt.yticks(fontsize =30)
plt.suptitle('CI_Subcat vs Priority', fontsize = 60)
# Out:
# Text(0.5, 0.98, 'CI_Subcat vs Priority')

# %% [markdown]
# ### 3. Distibution of Number of Reassignments with Priority

# %%
box( 'No_of_Reassignments', 20,10)

# %% [markdown]
# ### 3. Distibution of Closure Code with Priority

# %%
box( 'Closure_Code', 25,10)
plt.xticks(rotation = 90, fontsize = 15)
plt.yticks(fontsize = 15)
# Out:
# (array([0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. , 5.5]),
#  <a list of 11 Text major ticklabel objects>)

# %% [markdown]
# ### 3. Distibution of No_of_Related_Interactions with Priority

# %%
box( 'No_of_Related_Interactions',35,20)
plt.xticks(rotation= 45, fontsize = 20)
plt.yticks(fontsize = 20)
# Out:
# (array([0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. , 5.5]),
#  <a list of 11 Text major ticklabel objects>)

# %% [markdown]
# ### 3. Correation Map
# - Shows that impact has high correlation with Priority

# %%
sns.heatmap(df1.corr())
plt.xticks(rotation= 45, fontsize = 20)
plt.yticks(rotation = 45, fontsize = 20)

# %% [markdown]
# ### Modelling

# %% [markdown]
# ## Objective 3: Predicting the Handle Time

# %% [markdown]
# ### Data Wrangling

# %% [markdown]
# ### EDA

# %% [markdown]
# ####  Handle Time With year

# %% [markdown]
# <img src = "handle_time_hrs.png">
